# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('student_scores.csv')

# %%
dataset.shape
# Out:
# (25, 2)

# %%
dataset.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
dataset
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
dataset.plot(x='Hours', y='Scores', style='o')
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()

# %%
hours_mean = dataset['X'].mean()
score_mean = dataset['Y'].mean()
print(hours_mean,score_mean)
# Out:
# 5.012 51.48

# %%
# Out:
# 51.48

# %%
dataset['x'] = dataset['X'] - hours_mean
dataset['y'] = dataset['Y'] - score_mean

# %%
dataset
# Out:
#       X   Y      x      y        x*y        x^2        y^2  Y_prediction
# 0   2.5  21 -2.512 -30.48   76.56576   6.310144   929.0304     26.923182
# 1   5.1  47  0.088  -4.48   -0.39424   0.007744    20.0704     52.340271
# 2   3.2  27 -1.812 -24.48   44.35776   3.283344   599.2704     33.766244
# 3   8.5  75  3.488  23.52   82.03776  12.166144   553.1904     85.578002
# 4   3.5  30 -1.512 -21.48   32.47776   2.286144   461.3904     36.698985
# 5   1.5  20 -3.512 -31.48  110.55776  12.334144   990.9904     17.147378
# 6   9.2  88  4.188  36.52  152.94576  17.539344  1333.7104     92.421065
# 7   5.5  60  0.488   8.52    4.15776   0.238144    72.5904     56.250592
# 8   8.3  81  3.288  29.52   97.06176  10.810944   871.4304     83.622842
# 9   2.7  25 -2.312 -26.48   61.22176   5.345344   701.1904     28.878343
# 10  7.7  85  2.688  33.52   90.10176   7.225344  1123.5904     77.757360
# 11  5.9  62  0.888  10.52    9.34176   0.788544   110.6704     60.160913
# ...

# %%
dataset['x*y'] = dataset['x'] * dataset['y']

# %%
dataset
# Out:
#       X   Y      x      y        x*y        x^2        y^2  Y_prediction
# 0   2.5  21 -2.512 -30.48   76.56576   6.310144   929.0304     26.923182
# 1   5.1  47  0.088  -4.48   -0.39424   0.007744    20.0704     52.340271
# 2   3.2  27 -1.812 -24.48   44.35776   3.283344   599.2704     33.766244
# 3   8.5  75  3.488  23.52   82.03776  12.166144   553.1904     85.578002
# 4   3.5  30 -1.512 -21.48   32.47776   2.286144   461.3904     36.698985
# 5   1.5  20 -3.512 -31.48  110.55776  12.334144   990.9904     17.147378
# 6   9.2  88  4.188  36.52  152.94576  17.539344  1333.7104     92.421065
# 7   5.5  60  0.488   8.52    4.15776   0.238144    72.5904     56.250592
# 8   8.3  81  3.288  29.52   97.06176  10.810944   871.4304     83.622842
# 9   2.7  25 -2.312 -26.48   61.22176   5.345344   701.1904     28.878343
# 10  7.7  85  2.688  33.52   90.10176   7.225344  1123.5904     77.757360
# 11  5.9  62  0.888  10.52    9.34176   0.788544   110.6704     60.160913
# ...

# %%
dataset['x^2'] = dataset['x'] * dataset['x']
dataset['y^2'] = dataset['y'] * dataset['y']
dataset
# Out:
#       X   Y      x      y        x*y        x^2        y^2  Y_prediction
# 0   2.5  21 -2.512 -30.48   76.56576   6.310144   929.0304     26.923182
# 1   5.1  47  0.088  -4.48   -0.39424   0.007744    20.0704     52.340271
# 2   3.2  27 -1.812 -24.48   44.35776   3.283344   599.2704     33.766244
# 3   8.5  75  3.488  23.52   82.03776  12.166144   553.1904     85.578002
# 4   3.5  30 -1.512 -21.48   32.47776   2.286144   461.3904     36.698985
# 5   1.5  20 -3.512 -31.48  110.55776  12.334144   990.9904     17.147378
# 6   9.2  88  4.188  36.52  152.94576  17.539344  1333.7104     92.421065
# 7   5.5  60  0.488   8.52    4.15776   0.238144    72.5904     56.250592
# 8   8.3  81  3.288  29.52   97.06176  10.810944   871.4304     83.622842
# 9   2.7  25 -2.312 -26.48   61.22176   5.345344   701.1904     28.878343
# 10  7.7  85  2.688  33.52   90.10176   7.225344  1123.5904     77.757360
# 11  5.9  62  0.888  10.52    9.34176   0.788544   110.6704     60.160913
# ...

# %%
dataset.rename(columns = {'Hours':'X', 
                          'Scores':'Y',
                          'h=Hours-hours_mean':'x',
                          's=Scores-score_mean':'y',
                          'h*s':'x*y',
                          'h_square':'x^2','s_square':'y^2'}, inplace = True)

# %%
dataset
# Out:
#       X   Y      x      y        x*y        x^2        y^2  Y_prediction
# 0   2.5  21 -2.512 -30.48   76.56576   6.310144   929.0304     26.923182
# 1   5.1  47  0.088  -4.48   -0.39424   0.007744    20.0704     52.340271
# 2   3.2  27 -1.812 -24.48   44.35776   3.283344   599.2704     33.766244
# 3   8.5  75  3.488  23.52   82.03776  12.166144   553.1904     85.578002
# 4   3.5  30 -1.512 -21.48   32.47776   2.286144   461.3904     36.698985
# 5   1.5  20 -3.512 -31.48  110.55776  12.334144   990.9904     17.147378
# 6   9.2  88  4.188  36.52  152.94576  17.539344  1333.7104     92.421065
# 7   5.5  60  0.488   8.52    4.15776   0.238144    72.5904     56.250592
# 8   8.3  81  3.288  29.52   97.06176  10.810944   871.4304     83.622842
# 9   2.7  25 -2.312 -26.48   61.22176   5.345344   701.1904     28.878343
# 10  7.7  85  2.688  33.52   90.10176   7.225344  1123.5904     77.757360
# 11  5.9  62  0.888  10.52    9.34176   0.788544   110.6704     60.160913
# ...

# %%
x_squared_sum = dataset['x^2'].sum()
y_squared_sum = dataset['y^2'].sum()
summation_xy = dataset['x*y'].sum()

# %%
print(x_squared_sum,y_squared_sum,summation_xy)
# Out:
# 153.0264 15346.24 1495.9560000000001

# %%
# r ---> correlation of x and y
r = summation_xy/(x_squared_sum*y_squared_sum)**0.5
r
# Out:
# 0.9761906560220887

# %%
def standardDeviation(_numbers_list):
    mean = meanFunc(_numbers_list)
    list2 =[]
    for i in _numbers_list:
        list2.append((i-mean)**2)
    return meanFunc(list2)**0.5

std_x = standardDeviation(dataset['x'].tolist())
std_y = standardDeviation(dataset['y'].tolist())
print(std_x,std_y)
# Out:
# 2.47407679751458 24.775988375844868

# %%
# m = r * (Standard Deviation of y / Standard Deviation of x)

m = r * (std_y/std_x)
m
# Out:
# 9.775803390787473

# %%
# c---> y intercept
# c = mean of y - m * mean of x
c = dataset['Y'].mean() - m*dataset['X'].mean()
c
# Out:
# 2.4836734053731817

# %%
dataset['Y_prediction'] = m*dataset['X']+c
dataset
# Out:
#       X   Y      x      y        x*y        x^2        y^2  Y_prediction
# 0   2.5  21 -2.512 -30.48   76.56576   6.310144   929.0304     26.923182
# 1   5.1  47  0.088  -4.48   -0.39424   0.007744    20.0704     52.340271
# 2   3.2  27 -1.812 -24.48   44.35776   3.283344   599.2704     33.766244
# 3   8.5  75  3.488  23.52   82.03776  12.166144   553.1904     85.578002
# 4   3.5  30 -1.512 -21.48   32.47776   2.286144   461.3904     36.698985
# 5   1.5  20 -3.512 -31.48  110.55776  12.334144   990.9904     17.147378
# 6   9.2  88  4.188  36.52  152.94576  17.539344  1333.7104     92.421065
# 7   5.5  60  0.488   8.52    4.15776   0.238144    72.5904     56.250592
# 8   8.3  81  3.288  29.52   97.06176  10.810944   871.4304     83.622842
# 9   2.7  25 -2.312 -26.48   61.22176   5.345344   701.1904     28.878343
# 10  7.7  85  2.688  33.52   90.10176   7.225344  1123.5904     77.757360
# 11  5.9  62  0.888  10.52    9.34176   0.788544   110.6704     60.160913
# ...

# %%
graph1 = plt.scatter(dataset['X'],dataset['Y'])
graph2 = plt.scatter(dataset['X'],dataset['Y_prediction'])
plt.show()
